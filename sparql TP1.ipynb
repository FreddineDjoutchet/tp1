# %%
#title: Humans born in Schaerbeerk
import requests
from datetime import datetime as dt
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
endpoint = "https://query.wikidata.org/bigdata/namespace/wdq/sparql"
sparql = SPARQLWrapper(endpoint)

statement = """

select distinct ?item ?itemLabel ?itemDescription ?sitelinks 
where {
    # ?item wdt:P31 wd:Q5;  
          wdt:P19/wdt:P131* wd:Q12887; 
             wikibase:sitelinks ?sitelinks.
   
    SERVICE wikibase:label { bd:serviceParam wikibase:language "en,nl" }
}
ORDER BY DESC(?sitelinks)
"""
sparql.setQuery(statement)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

rows = results['results']['bindings']
print(f"\n{len(rows)} Human born in Schaerbeek found\n")
print(rows)
# Out:
# 277 Human born in Schaerbeek found
#
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1666'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Jacques Brel'}, 'itemDescription': {'xml:lang': 'en', 'type': 'literal', 'value': 'Belgian singer-songwriter'}, 'sitelinks': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '80'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q155691'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Paul-Henri Spaak'}, 'itemDescription': {'xml:lang': 'en', 'type': 'literal', 'value': 'Belgian politician (1899-1972)'}, 'sitelinks': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '50'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q309995'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Paul Deschanel'}, 'itemDescription': {'xml:lang': 'en', 'type': 'literal', 'value': '11th President of the French Republic (1855-1922)'}, 'sitelinks': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '50'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q309945'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Peyo'}, 'itemDescription': {'xml:lang': 'en', 'type': 'literal', 'value': 'Belgian comics cartoonist and scriptwriter'}, 'sitelinks': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '34'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q328248'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Pierre Alechinsky'}, 'itemDescription': {'xml:lang': 'en', 'type': 'literal', 'value': 'Belgian and French painter and engraver'}, 'sitelinks': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '32'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q235896'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Natacha Atlas'}, 'itemDescription': {'xml:lang': 'en', 'type': 'literal', 'value': 'Belgian Egyptian-British recording artist, singer'}, 'sitelinks': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '28'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q602873'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Georges Grün'}, 'itemDescription': {'xml:lang': 'en', 'type': 'literal', 'value': 'Belgian association football player'}, 'sitelinks': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '23'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q469580'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Joseph Cardijn'}, 'itemDescription': {'xml:lang': 'en', 'type': 'literal', 'value': '20th century Belgian cardinal, founder of the Young Christian Workers'}, 'sitelinks': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '22'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q559783'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Benoît Sokal'}, 'itemDescription': {'xml:lang': 'en', 'type': 'literal', 'value': 'Belgian comic writer, video game developer'}, 'sitelinks': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '21'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3560737'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Virginie Efira'}, 'itemDescription': {'xml:lang': 'en', 'type': 'literal', 'value': 'Belgian actress and television presenter'}, 'sitelinks': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '20'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2627259'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Marie Popelin'}, 'itemDescription': {'xml:lang': 'en', 'type': 'literal', 'value': 'advocate, educator, feminist'}, 'siteli ...
